# %%
#pip install holidays

# %%
# Basic imports
import numpy as np
import pandas as pd
import datetime # manipulating date formats
import itertools
import time
import holidays
import os

from math import sqrt
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as MSE, r2_score, mean_absolute_percentage_error as MAPE
from sklearn import datasets, linear_model

# Stats packages
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.statespace.tools import diff
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.stats.diagnostic import acorr_ljungbox
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm

import warnings
warnings.filterwarnings("ignore")

# %%
nyc_v = pd.read_csv("/Users/sameshbajaj/Desktop/Time Series Analysis/Assignments/Project/nyc_violent_final copy.csv", parse_dates=['date'])
nyc_temp = pd.read_csv("/Users/sameshbajaj/Desktop/Time Series Analysis/Assignments/Project/ISYE6203_NYC_avg_temp_2009-2020.csv", parse_dates=['date'])
holiday = pd.get_dummies(pd.read_csv("/Users/sameshbajaj/Desktop/Time Series Analysis/Assignments/Project/Holidays_2009-2020.csv", parse_dates=['date']))

# %%
nyc_v = nyc_v.set_index("date")
nyc_temp = nyc_temp.set_index("date")
holiday = holiday.set_index("date")

# %%
nyc_v.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
nyc_temp
# Out:
#             avgTemp
# date
# 2009-01-01    20.57
# 2009-01-02    28.49
# 2009-01-03    33.44
# 2009-01-04    33.53
# 2009-01-05    40.46
# ...             ...
# 2020-12-27    30.65
# 2020-12-28    42.53
# 2020-12-29    36.59
# 2020-12-30    35.60
# 2020-12-31    41.99
#
# [4383 rows x 1 columns]

# %%
nyc_temp.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
def test_stationarity(timeseries):
    # Perform Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries,maxlag=7*4, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (round(dfoutput,3))

# %%
test_stationarity(nyc_v)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -4.165
# p-value                           0.001
# #Lags Used                       28.000
# Number of Observations Used    4354.000
# Critical Value (1%)              -3.432
# Critical Value (5%)              -2.862
# Critical Value (10%)             -2.567
# dtype: float64

# %%
acf=plot_acf(nyc_v)
pacf=plot_pacf(nyc_v)

# %%
train_end = '2020-12-24'
#test_start = '2020-12-18'
test_end = '2020-12-31'
demo_start = '2020-10-31'
demo = nyc_v[demo_start:test_end]
nyc_v_train, nyc_v_test = nyc_v[:train_end], nyc_v[train_end:]

nyc_v_train.plot(figsize=(12,6), style='o', grid=True)
# Out:
# <AxesSubplot:xlabel='date'>

# %%
begin = '2009-01-01'
abv = '2020-12-30'

exo = nyc_temp.copy()
exo_train,exo_test = exo[:train_end], exo[train_end:abv]
exo_test
# Out:
#             avgTemp
# date
# 2020-12-24    50.99
# 2020-12-25    45.05
# 2020-12-26    28.13
# 2020-12-27    30.65
# 2020-12-28    42.53
# 2020-12-29    36.59
# 2020-12-30    35.60

# %%
exo_train.shape
# Out:
# (4376, 1)

# %%
exo_test.shape
# Out:
# (7, 1)

# %%
nyc_v_train.shape
# Out:
# (4376, 1)

# %%
nyc_v_test.shape
# Out:
# (8, 1)

# %%
def sarimax(ts,exo,all_param):
    results = []
    for param in all_param:
        try:
            mod = SARIMAX(ts,
                          exog = exo,
                          order=param[0],
                          seasonal_order=param[1])
            res = mod.fit()
            results.append((res,res.aic,param))
            print('Tried out SARIMAX{}x{} - AIC:{}'.format(param[0], param[1], round(res.aic,2)))
        except Exception as e:
            print(e)
            continue
            
    return results

# %%
# set parameter range
p,d,q = range(0,2),[1],range(0,2)
P,D,Q,s = range(0,2),[1],range(0,2),[7]
# list of all parameter combos
pdq = list(itertools.product(p, d, q))
seasonal_pdq = list(itertools.product(P, D, Q, s))
all_param = list(itertools.product(pdq,seasonal_pdq))

# %%
all_res = sarimax(nyc_v_train,exo_train,all_param)
# Out:
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  9.19807D+00    |proj g|=  2.49034D-04
#
# At iterate    5    f=  5.51367D+00    |proj g|=  1.44684D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5     27      1     0     0   1.447D-06   5.514D+00
#   F =   5.5136731338058400
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Tried out SARIMAX(0, 1, 0)x(0, 1, 0, 7) - AIC:48259.67
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.26840D+00    |proj g|=  6.21123D-02
#  This problem is unconstrained.
# At iterate    5    f=  5.20642D+00    |proj g|=  7.09933D-03
#
# At iterate   10    f=  5.19822D+00    |proj g|=  7.55121D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     13     15      1     0     0   4.137D-06   5.198D+00
#   F =   5.1982084059144018
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Tried out SARIMAX(0, 1, 0)x(0, 1, 1, 7) - AIC:45500.72
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.37025D+00    |proj g|=  4.30319D-03
#  This problem is unconstrained.
# At iterate    5    f=  5.37022D+00    |proj g|=  9.10762D-04
#
# At iterate   10    f=  5.37021D+00    |proj g|=  2.04601D-03
#
# At iterate   15    f=  5.37020D+00    |proj g|=  2.07123D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     15     17      1     0     0   2.071D-06   5.370D+00
#   F =   5.3701991274983696
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Tried out SARIMAX(0, 1, 0)x(1, 1, 0, 7) - AIC:47005.98
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.30803D+00    |proj g|=  1.11796D-01
#  This problem is unconstrained.
# At iterate    5    f=  5.22199D+00    |proj g|=  1.16235D-02
#
# At iterate   10    f=  5.19759D+00    |proj g|=  1.35967D-03
#
# At iterate   15    f=  5.19752D+00    |proj g|=  2.92149D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     18     21      1     0     0   1.770D-05   5.198D+00
#   F =   5.1975157257650180
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Tried out SARIMAX(0, 1, 0)x(1, 1, 1, 7) - AIC:45496.66
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.29970D+00    |proj g|=  7.52674D-02
#  This problem is unconstrained.
# At iterate    5    f=  5.23017D+00    |proj g|=  5.46244D-03
#
# At iterate   10    f=  5.22037D+00    |proj g|=  4.57242D-04
#
# At iterate   15    f=  5.21915D+00    |proj g|=  1.08059D-04
#
# At iterate   20    f=  5.21903D+00    |proj g|=  1.33933D-04
#
# At iterate   25    f=  5.21901D+00    |proj g|=  7.24762D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     25     26      1     0     0   7.248D-06   5.219D+00
#   F =   5.2190126934122532
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Tried out SARIMAX(0, 1, 1)x(0, 1, 0, 7) - AIC:45682.8
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.09985D+00    |proj g|=  5.23694D-02
#  This problem is unconstrained.
# At iterate    5    f=  4.98414D+00    |proj g|=  2.24670D-02
#
# At iterate   10    f=  4.93531D+00    |proj g|=  1.48897D-02
#
# At iterate   15    f=  4.93294D+00    |proj g|=  1.46523D-04
#
# At iterate   20    f=  4.93274D+00    |proj g|=  7.32877D-05
#
# At iterate   25    f=  4.93273D+00    |proj g|=  6.22080D-07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     25     35      1     0     0   6.221D-07   4.933D+00
#   F =   4.9327338798195886
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Tried out SARIMAX(0, 1, 1)x(0, 1, 1, 7) - AIC:43179.29
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.17416D+00    |proj g|=  6.50758D-02
#  This problem is unconstrained.
# At iterate    5    f=  5.11576D+00    |proj g|=  6.68915D-03
#
# At iterate   10    f=  5.07779D+00    |proj g|=  1.45454D-04
#
# At iterate   15    f=  5.07736D+00    |proj g|=  1.24507D-03
#
# At iterate   20    f=  5.07697D+00    |proj g|=  7.21294D-04
#
# At iterate   25    f=  5.07695D+00    |proj g|=  3.72672D-04
#
# At iterate   30    f=  5.07694D+00    |proj g|=  1.80709D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     31     37      1     0     0   7.650D-06   5.077D+00
#   F =   5.0769439926297855
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Tried out SARIMAX(0, 1, 1)x(1, 1, 0, 7) - AIC:44441.41
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.13007D+00    |proj g|=  7.91198D-02
#  This problem is unconstrained.
# At iterate    5    f=  5.03319D+00    |proj g|=  1.02823D-02
#
# At iterate   10    f=  4.94544D+00    |proj g|=  1.21138D-02
#
# At iterate   15    f=  4.93381D+00    |proj g|=  4.86078D-02
#
# At iterate   20    f=  4.93201D+00    |proj g|=  1.79806D-04
#
# At iterate   25    f=  4.93201D+00    |proj g|=  3.63647D-04
#
# At iterate   30    f=  4.93200D+00    |proj g|=  2.46052D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     31     40      1     0     0   2.186D-05   4.932D+00
#   F =   4.9319977394876693
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Tried out SARIMAX(0, 1, 1)x(1, 1, 1, 7) - AIC:43174.84
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.39911D+00    |proj g|=  4.25273D-03
#  This problem is unconstrained.
# At iterate    5    f=  5.39886D+00    |proj g|=  5.57385D-04
#
# At iterate   10    f=  5.39885D+00    |proj g|=  1.63420D-03
#
# At iterate   15    f=  5.39883D+00    |proj g|=  3.46230D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     15     17      1     0     0   3.462D-06   5.399D+00
#   F =   5.3988334579645700
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Tried out SARIMAX(1, 1, 0)x(0, 1, 0, 7) - AIC:47256.59
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.19502D+00    |proj g|=  4.63497D-02
#  This problem is unconstrained.
# At iterate    5    f=  5.09988D+00    |proj g|=  7.19004D-03
#
# At iterate   10    f=  5.09454D+00    |proj g|=  2.56442D-04
#
# At iterate   15    f=  5.09411D+00    |proj g|=  1.69904D-03
#
# At iterate   20    f=  5.09400D+00    |proj g|=  2.18829D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     20     25      1     0     0   2.188D-06   5.094D+00
#   F =   5.0940012144704943
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Tried out SARIMAX(1, 1, 0)x(0, 1, 1, 7) - AIC:44590.7
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.27411D+00    |proj g|=  4.46074D-03
#  This problem is unconstrained.
# At iterate    5    f=  5.26330D+00    |proj g|=  1.60117D-02
#
# At iterate   10    f=  5.25682D+00    |proj g|=  2.93669D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     11     14      1     0     0   1.616D-06   5.257D+00
#   F =   5.2568193138852983
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Tried out SARIMAX(1, 1, 0)x(1, 1, 0, 7) - AIC:46015.68
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.22898D+00    |proj g|=  7.85746D-02
#  This problem is unconstrained.
# At iterate    5    f=  5.16809D+00    |proj g|=  8.33912D-03
#
# At iterate   10    f=  5.09439D+00    |proj g|=  1.06818D-02
#
# At iterate   15    f=  5.09382D+00    |proj g|=  1.61225D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     15     20      1     0     0   1.612D-05   5.094D+00
#   F =   5.0938225385247895
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Tried out SARIMAX(1, 1, 0)x(1, 1, 1, 7) - AIC:44591.13
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.28932D+00    |proj g|=  8.80255D-02
#  This problem is unconstrained.
# At iterate    5    f=  5.23372D+00    |proj g|=  7.90456D-03
#
# At iterate   10    f=  5.21740D+00    |proj g|=  8.10306D-03
#
# At iterate   15    f=  5.21535D+00    |proj g|=  4.97060D-03
#
# At iterate   20    f=  5.21512D+00    |proj g|=  1.54754D-04
#
# At iterate   25    f=  5.21510D+00    |proj g|=  1.08968D-05
#
# At iterate   30    f=  5.21510D+00    |proj g|=  3.40194D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     30     40      1     0     0   3.402D-05   5.215D+00
#   F =   5.2150998853227790
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Tried out SARIMAX(1, 1, 1)x(0, 1, 0, 7) - AIC:45650.55
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.09243D+00    |proj g|=  6.13309D-02
#  This problem is unconstrained.
# At iterate    5    f=  5.02968D+00    |proj g|=  1.03894D-02
#
# At iterate   10    f=  4.94292D+00    |proj g|=  3.72096D-03
#
# At iterate   15    f=  4.92962D+00    |proj g|=  1.20455D-02
#
# At iterate   20    f=  4.92915D+00    |proj g|=  1.50832D-04
#
# At iterate   25    f=  4.92913D+00    |proj g|=  1.28689D-03
#
# At iterate   30    f=  4.92901D+00    |proj g|=  2.19445D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     34     45      1     0     0   2.049D-05   4.929D+00
#   F =   4.9290051650713043
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Tried out SARIMAX(1, 1, 1)x(0, 1, 1, 7) - AIC:43148.65
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.16560D+00    |proj g|=  7.86616D-02
#  This problem is unconstrained.
# At iterate    5    f=  5.12530D+00    |proj g|=  1.91245D-02
#
# At iterate   10    f=  5.07375D+00    |proj g|=  7.40012D-03
#
# At iterate   15    f=  5.07314D+00    |proj g|=  3.01584D-04
#
# At iterate   20    f=  5.07308D+00    |proj g|=  2.36876D-03
#
# At iterate   25    f=  5.07302D+00    |proj g|=  8.51354D-04
#
# At iterate   30    f=  5.07301D+00    |proj g|=  1.19331D-04
#
# At iterate   35    f=  5.07301D+00    |proj g|=  2.11490D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     37     46      1     0     0   7.339D-05   5.073D+00
#   F =   5.0730084014713652
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Tried out SARIMAX(1, 1, 1)x(1, 1, 0, 7) - AIC:44408.97
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            6     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.12214D+00    |proj g|=  7.87128D-02
#  This problem is unconstrained.
# At iterate    5    f=  5.04789D+00    |proj g|=  2.71157D-02
#
# At iterate   10    f=  4.95181D+00    |proj g|=  7.62935D-02
#
# At iterate   15    f=  4.94110D+00    |proj g|=  1.14519D-02
#
# At iterate   20    f=  4.92886D+00    |proj g|=  7.89140D-03
#
# At iterate   25    f=  4.92815D+00    |proj g|=  3.65250D-04
#
# At iterate   30    f=  4.92802D+00    |proj g|=  5.05910D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     6     33     47      1     0     0   1.444D-05   4.928D+00
#   F =   4.9280114396916002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Tried out SARIMAX(1, 1, 1)x(1, 1, 1, 7) - AIC:43141.96

# %%
all_res.sort(key=lambda x: x[1])
all_res[:5]
# Out:
# [(<statsmodels.tsa.statespace.sarimax.SARIMAXResultsWrapper at 0x7fd3c0606670>,
#   43141.95612018088,
#   ((1, 1, 1), (1, 1, 1, 7))),
#  (<statsmodels.tsa.statespace.sarimax.SARIMAXResultsWrapper at 0x7fd3c06069a0>,
#   43148.65320470405,
#   ((1, 1, 1), (0, 1, 1, 7))),
#  (<statsmodels.tsa.statespace.sarimax.SARIMAXResultsWrapper at 0x7fd3e95a6f70>,
#   43174.84421599608,
#   ((0, 1, 1), (1, 1, 1, 7))),
#  (<statsmodels.tsa.statespace.sarimax.SARIMAXResultsWrapper at 0x7fd3e957aac0>,
#   43179.28691618104,
#   ((0, 1, 1), (0, 1, 1, 7))),
#  (<statsmodels.tsa.statespace.sarimax.SARIMAXResultsWrapper at 0x7fd3d1a74160>,
#   44408.969529677386,
#   ((1, 1, 1), (1, 1, 0, 7)))]

# %%
res = all_res[0][0]
res.plot_diagnostics(figsize=(15, 12))

plt.show()
print("Ljung-box p-values:\n" + str(res.test_serial_correlation(method='ljungbox')[0][1]))
res.summary()
# Out:
# Ljung-box p-values:
# [4.38215249e-01 4.67607558e-01 5.27617425e-01 5.58009254e-01
#  3.49409231e-01 4.71238463e-01 4.45058740e-01 2.29843123e-01
#  2.81245205e-01 3.26023626e-01 3.73072757e-01 3.35657063e-01
#  2.94251936e-01 5.07188275e-04]
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# =========================================================================================
# Dep. Variable:                       crime count   No. Observations:                 4376
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 7)   Log Likelihood              -21564.978
# Date:                           Tue, 26 Apr 2022   AIC                          43141.956
# Time:                                   16:45:04   BIC                          43180.248
# Sample:                               01-01-2009   HQIC                         43155.469
#                                     - 12-24-2020
# Covariance Type:                             opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# avgTemp        1.5655      0.066     23.885      0.000       1.437       1.694
# ar.L1          0.0966      0.011      8.897      0.000       0.075       0.118
# ma.L1         -0.9535      0.005   -188.475      0.000      -0.963      -0.944
# ar.S.L7        0.0474      0.014      3.402      0.001       0.020       0.075
# ma.S.L7       -0.9920      0.003   -374.980      0.000      -0.997      -0.987
# sigma2      1128.6396      4.906    230.030      0.000    1119.023    1138.256
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.60   Jarque-Bera (JB):            536067.67
# Prob(Q):                              0.44   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.73   Skew:                             4.42
# Prob(H) (two-sided):                  0.00   Kurtosis:                        56.55
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
def pm(y_true, y_pred):
    return sum((y_true-y_pred)**2)/sum((y_true-np.mean(y_true))**2)

# %%
pred_test = res.get_prediction(start=train_end,end=test_end,exog=exo_test)
err = ('\nPM: %.2f'% pm(nyc_v_test['crime count'], pred_test.predicted_mean.to_frame()['predicted_mean']) + \
      '\nMean absolute percentage error: %.2f'% MAPE(nyc_v_test, pred_test.predicted_mean) + \
      '\nRoot mean squared error: %.2f'% sqrt(MSE(nyc_v_test, pred_test.predicted_mean)))

pred = res.get_prediction(start=begin,end=test_end,exog=exo_test)
pred_ci = pred.conf_int()

fig, ax = plt.subplots(figsize=(12,7))
ax.set(title='NYC Violent Crime', ylabel='Number of Incidents')

nyc_v.plot(ax=ax, style = 'o')
pred.predicted_mean.plot(ax=ax, style='o')
ci = pred_ci.loc[demo_start:]
ax.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], color='r', alpha=0.1)

plt.figtext(0.12, -0.06, err, ha="left",fontsize=15,va='center')
legend = ax.legend(["Train Set Observed","Test Set Observed", "Forecast"])

# %%
pred_test = res.get_prediction(start=train_end,end=test_end,exog=exo_test)
# The root mean squared error
err = ('\nPM: %.2f'% pm(nyc_v_test['crime count'], pred_test.predicted_mean.to_frame()['predicted_mean']) + \
      '\nMean absolute percentage error: %.2f'% MAPE(nyc_v_test, pred_test.predicted_mean) + \
      '\nRoot mean squared error: %.2f'% sqrt(MSE(nyc_v_test, pred_test.predicted_mean)))

pred = res.get_prediction(start=demo_start,end=test_end,exog=exo_test)
pred_ci = pred.conf_int()

fig, ax = plt.subplots(figsize=(12,7))
ax.set(title='NYC Violent Crime', ylabel='Number of Incidents')

nyc_v_train[demo_start:].plot(ax=ax)
nyc_v_test.plot(ax=ax)
pred.predicted_mean.plot(ax=ax)
ci = pred_ci.loc[demo_start:]
ax.fill_between(ci.index, ci.iloc[:,0], ci.iloc[:,1], color='r', alpha=0.1)

plt.figtext(0.12, -0.06, err, ha="left",fontsize=15,va='center')
legend = ax.legend(["Train Set Observed","Test Set Observed", "Forecast"])
ax.grid(True)
